# %%
import funcoes
from funcoes import *

# %%
from funcoes import somar

somar()
multi()
# Out:
# Esta funcao vai somar valores
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d0191e20f921> in <module>()
#       2
#       3 somar()
# ----> 4 multi()
#
# NameError: name 'multi' is not defined

# %%
from funcoes import multi

multi()
# Out:
# Esta funcao vai multiplicar valores
# Esta funcao vai somar valores

# %%
from items.cadastro import cliente

cliente()
# Out:
# Cadastro do cliente

# %%
from index import find_index


lista1 = ['a', 'b', 'c', 'd', 'e']

var1 = find_index(lista1, 'b')
print(var1)
# Out:
# 1

# %%
from index import find_index


lista1 = ['a', 'b', 'c', 'd', 'e']

var1 = find_index(lista1, 'f')
print(var1)
# Out:
# -1
